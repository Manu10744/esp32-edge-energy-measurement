# %% [markdown]
# ### Inference of Energy Consumption to serverless functions
# This script is dedicated to demonstrate the concept of distributing the energy consumption of a system to the serverless functions that are deployed to it.
#
# To this end, the CPU Usage of the serverless function containers during time interval t is put into relation with the total CPU Usage of the system during time interval t and then multiplied with the measured energy consumption measured during time interval t.

# %%
# Imports
import requests
import logging
import json
import time

logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(name)s - %(levelname)s >>> %(message)s',
                        handlers=[logging.StreamHandler()])
logger = logging.getLogger(__name__)

# %%
# Data collection settings
DATA_COLLECTION_INTERVAL_SECONDS = 60

# Prometheus settings
PROMETHEUS_BASE_URL = "http://localhost:30009"
REST_API_PATH = "/api/v1/query"

# %%
def prom_instant_query(query_str: str) -> dict: 
    """ Executes a Prometheus API Query using the given query. """
    query_url = f"{PROMETHEUS_BASE_URL}/{REST_API_PATH}"
    response = requests.get(query_url, params={'query': query_str})
    
    if response:
        return response.json()
    else:
        logger.info(f"API Request ({response.url}) was not successful: HTTP {response.status_code}")
        return dict()

def get_fn_container_cpu_usages(namespace: str = "openfaas-fn"):
    """ Returns the CPU usage of all serverless function containers in the given namespace. """
    query = "rate(container_cpu_usage_seconds_total{image!='', namespace='openfaas-fn', container_name!='POD'}[1m]) > 0"
    query_result = prom_instant_query(query_str=query)
    
    if query_result:
        logger.info("FUNCTION CONTAINER CPU USAGES")
        logger.info(json.dumps(query_result, indent=4))
        return query_result
    else:
        logger.error(f"Failed to retrieve the CPU Usages of containers in namespace {namespace}.")
        return dict()
    
def get_container_cpu_usage_sum(container_name: str, node: str):
    """ Returns the sum of the CPU usage of all containers with the given container_name on the given
        node. """
    query = "sum(rate(container_cpu_usage_seconds_total{image!='', container='%s', container_name!='POD', node='%s'}[1m]))" % (container_name, node)
    query_result = prom_instant_query(query_str=query)
    
    if query_result:
        logger.info(f"SUM OF CPU USAGE OF CONTAINER {container_name.upper()} ON NODE {node.upper()}")
        logger.info(json.dumps(query_result, indent=4))
        timestamp, sum_cpu_usage = tuple(query_result['data']['result'][0]['value'])
        return sum_cpu_usage
    else:
        logger.error(f"Failed to retrieve the container CPU usage sum for '{container_name}' on node '{node}'")
        return dict()
    
def get_node_cpu_usage_sum(node: str):
    """ Returns the sum of the CPU usage of all containers on the given node. """
    query = "sum(rate(container_cpu_usage_seconds_total{image!='', container_name!='POD', node='%s'}[1m]))" % node
    query_result = prom_instant_query(query_str=query)
    
    if query_result:
        logger.info(f"NODE CPU USAGE SUM OF NODE {node.upper()}")
        logger.info(json.dumps(query_result, indent=4))
        timestamp, sum_cpu_usage = tuple(query_result['data']['result'][0]['value'])
        return sum_cpu_usage
    else:
        logger.error(f"Failed to retrieve the node cpu usage sum of node '{node}'")
        return dict()
    
def get_node_energy_consumption(node: str):
    """ Returns the energy consumption of the given node. """
    query = "idelta(powerexporter_power_consumption_ampere_seconds_total{instance='%s'}[2m:1m])" % node
    query_result = prom_instant_query(query_str=query)
    
    if query_result:
        logger.info(f"ENERGY CONSUMPTION OF NODE {node.upper()}")
        logger.info(json.dumps(query_result, indent=4))
        timestamp, energy_consumption = tuple(query_result['data']['result'][0]['value'])
        return energy_consumption
    else:
        logger.error(f"Failed to retrieve the energy consumption of node '{node}'")
        return dict()
    
def collect_data():
    while True:
        container_map = dict()
        energy_map = dict()
        # Step 1: Get CPU usage of all containers in openfaas-fn
        # This gives us two things in 1 query:
        #   1) the various serverless functions that were deployed in the time frame
        #   2) the deployment node per container
        fn_container_cpu_usages = get_fn_container_cpu_usages()
        for fn_container in fn_container_cpu_usages['data']['result']:
            container_name = fn_container['metric']['container']
            
            node = fn_container['metric']['node']
            # Step 2: Get Node CPU Usage as sum of cpu usage of all containers
            sum_node_cpu_usage = get_node_cpu_usage_sum(node)
            
            # Step 3: Get energy consumption of node
            if node not in energy_map:
                energy_consumption = get_node_energy_consumption(node)
                energy_map.update({node: float(energy_consumption)})
                
            cpu_usages_per_node = container_map.setdefault(container_name, dict()) # node -> cpu usage of fn containers
            if node not in cpu_usages_per_node:
                sum_cpu_usage_container = get_container_cpu_usage_sum(container_name, node)
                cpu_usages_per_node.update({node: float(sum_cpu_usage_container) / float(sum_node_cpu_usage)})
            
            logger.info(energy_map)
            logger.info(container_map)
            
            logger.info("==============================================================")
            # Print results:
            for node in energy_map:
                logger.info(f"Energy Consumption of {node} = {energy_map.get(node)}")
                
            for function, cpu_per_node in container_map.items():
                for node, cpu_usage in cpu_per_node.items():
                    logger.info(f"Energy Consumption ({function} | {node}) = {cpu_usage * energy_map.get(node)}")
            
        
        logger.info(f"Sleeping for {DATA_COLLECTION_INTERVAL_SECONDS} seconds ...")
        time.sleep(DATA_COLLECTION_INTERVAL_SECONDS)

# %%
# Collect data and distribute energy consumption until CTRL + C
collect_data()
# Out:
# 2022-08-02 18:05:47,473 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:05:47,477 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "analyze-sentence",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/podf180d417-a88c-481b-878c-f0d798ff4518/cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "image": "docker.io/phyz1x/analyze-sentence:1.0.0",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "analyze-sentence-6f64d86778-96l9f",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456346.175,
#                     "0.00508473333332707"
#                 ]
#             },
#             {
#                 "metric": {
#                     "container": "nodeinfo",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/pod57d80e61-eb4a-40fb-afce-c09dffd6f567/0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "image": "ghcr.io/openfaas/nodeinfo:latest",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-cbbfc686d-sv5xm",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456346.175,
#                     "0.0036785111111111092"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:05:47,573 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:05:47,574 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456346.275,
#                     "0.07207079999997319"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:05:47,671 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:05:47,672 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659456346.374,
#                     "8.564088506282133"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:05:47,771 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:05:47,772 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456346.474,
#                     "0.00508473333332707"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:05:47,772 - __main__ - INFO >>> {'odroidxu4-1': 8.564088506282133}
# 2022-08-02 18:05:47,773 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.0705519202413316}}
# 2022-08-02 18:05:47,773 - __main__ - INFO >>> =================================================
# 2022-08-02 18:05:47,774 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 8.564088506282133
# 2022-08-02 18:05:47,774 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.6042128892349217
# 2022-08-02 18:05:47,870 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:05:47,871 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456346.573,
#                     "0.07207079999997319"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:05:47,970 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:05:47,970 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456346.672,
#                     "0.0036785111111111092"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:05:47,971 - __main__ - INFO >>> {'odroidxu4-1': 8.564088506282133}
# 2022-08-02 18:05:47,971 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.0705519202413316}, 'nodeinfo': {'odroidxu4-1': 0.05104024252696623}}
# 2022-08-02 18:05:47,972 - __main__ - INFO >>> =================================================
# 2022-08-02 18:05:47,972 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 8.564088506282133
# 2022-08-02 18:05:47,973 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.6042128892349217
# 2022-08-02 18:05:47,973 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 0.437113154383044
# 2022-08-02 18:05:47,974 - __main__ - INFO >>> Sleeping for 60 seconds ...
# 2022-08-02 18:06:48,108 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:06:48,111 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "analyze-sentence",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/podf180d417-a88c-481b-878c-f0d798ff4518/cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "image": "docker.io/phyz1x/analyze-sentence:1.0.0",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "analyze-sentence-6f64d86778-96l9f",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456406.805,
#                     "0.0031144444444281463"
#                 ]
#             },
#             {
#                 "metric": {
#                     "container": "nodeinfo",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/pod57d80e61-eb4a-40fb-afce-c09dffd6f567/0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "image": "ghcr.io/openfaas/nodeinfo:latest",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-cbbfc686d-sv5xm",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456406.805,
#                     "0.004052444444444426"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:06:48,228 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:06:48,229 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456406.928,
#                     "0.09156813333331335"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:06:48,329 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:06:48,330 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659456407.029,
#                     "8.56039399600013"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:06:48,444 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:06:48,445 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456407.144,
#                     "0.0031144444444281463"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:06:48,446 - __main__ - INFO >>> {'odroidxu4-1': 8.56039399600013}
# 2022-08-02 18:06:48,447 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.0340123177251128}}
# 2022-08-02 18:06:48,447 - __main__ - INFO >>> =================================================
# 2022-08-02 18:06:48,448 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 8.56039399600013
# 2022-08-02 18:06:48,450 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.29115884044410445
# 2022-08-02 18:06:48,564 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:06:48,568 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456407.261,
#                     "0.09156813333331335"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:06:48,684 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:06:48,685 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456407.386,
#                     "0.004052444444444426"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:06:48,686 - __main__ - INFO >>> {'odroidxu4-1': 8.56039399600013}
# 2022-08-02 18:06:48,686 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.0340123177251128}, 'nodeinfo': {'odroidxu4-1': 0.044256056085508394}}
# 2022-08-02 18:06:48,687 - __main__ - INFO >>> =================================================
# 2022-08-02 18:06:48,688 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 8.56039399600013
# 2022-08-02 18:06:48,689 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.29115884044410445
# 2022-08-02 18:06:48,689 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 0.3788492768010311
# 2022-08-02 18:06:48,690 - __main__ - INFO >>> Sleeping for 60 seconds ...
# 2022-08-02 18:07:48,809 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:07:48,810 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "analyze-sentence",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/podf180d417-a88c-481b-878c-f0d798ff4518/cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "image": "docker.io/phyz1x/analyze-sentence:1.0.0",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "analyze-sentence-6f64d86778-96l9f",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456467.509,
#                     "9.287946955555565"
#                 ]
#             },
#             {
#                 "metric": {
#                     "container": "nodeinfo",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/pod57d80e61-eb4a-40fb-afce-c09dffd6f567/0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "image": "ghcr.io/openfaas/nodeinfo:latest",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-cbbfc686d-sv5xm",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456467.509,
#                     "0.0008888444444444587"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:07:48,911 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:07:48,912 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456467.611,
#                     "9.313080111111105"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:07:49,011 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:07:49,015 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659456467.706,
#                     "32.27491204762373"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:07:49,128 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:07:49,129 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456467.827,
#                     "9.287946955555565"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:07:49,131 - __main__ - INFO >>> {'odroidxu4-1': 32.27491204762373}
# 2022-08-02 18:07:49,132 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.9973013057704126}}
# 2022-08-02 18:07:49,133 - __main__ - INFO >>> =================================================
# 2022-08-02 18:07:49,134 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 32.27491204762373
# 2022-08-02 18:07:49,134 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 32.187811928720365
# 2022-08-02 18:07:49,231 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:07:49,232 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456467.931,
#                     "9.313080111111105"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:07:49,334 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:07:49,335 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456468.03,
#                     "0.0008888444444444587"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:07:49,336 - __main__ - INFO >>> {'odroidxu4-1': 32.27491204762373}
# 2022-08-02 18:07:49,336 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.9973013057704126}, 'nodeinfo': {'odroidxu4-1': 9.544043794748528e-05}}
# 2022-08-02 18:07:49,337 - __main__ - INFO >>> =================================================
# 2022-08-02 18:07:49,338 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 32.27491204762373
# 2022-08-02 18:07:49,339 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 32.187811928720365
# 2022-08-02 18:07:49,340 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 0.0030803317405417776
# 2022-08-02 18:07:49,341 - __main__ - INFO >>> Sleeping for 60 seconds ...
# 2022-08-02 18:08:49,461 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:08:49,462 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "analyze-sentence",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/podf180d417-a88c-481b-878c-f0d798ff4518/cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "image": "docker.io/phyz1x/analyze-sentence:1.0.0",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "analyze-sentence-6f64d86778-96l9f",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456528.16,
#                     "6.636978044444468"
#                 ]
#             },
#             {
#                 "metric": {
#                     "container": "nodeinfo",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/pod57d80e61-eb4a-40fb-afce-c09dffd6f567/0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "image": "ghcr.io/openfaas/nodeinfo:latest",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-cbbfc686d-sv5xm",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456528.16,
#                     "0.0014818888888888811"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:08:49,565 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:08:49,566 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456528.264,
#                     "6.656544955555618"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:08:49,664 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:08:49,666 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659456528.363,
#                     "63.346956695080735"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:08:49,767 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:08:49,768 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456528.467,
#                     "6.636978044444468"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:08:49,768 - __main__ - INFO >>> {'odroidxu4-1': 63.346956695080735}
# 2022-08-02 18:08:49,769 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.9970605004184911}}
# 2022-08-02 18:08:49,771 - __main__ - INFO >>> =================================================
# 2022-08-02 18:08:49,771 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 63.346956695080735
# 2022-08-02 18:08:49,772 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 63.16074834238569
# 2022-08-02 18:08:49,877 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:08:49,881 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456528.572,
#                     "6.656544955555618"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:08:49,984 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:08:49,985 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456528.683,
#                     "0.0014818888888888811"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:08:49,985 - __main__ - INFO >>> {'odroidxu4-1': 63.346956695080735}
# 2022-08-02 18:08:49,986 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.9970605004184911}, 'nodeinfo': {'odroidxu4-1': 0.00022262132965121523}}
# 2022-08-02 18:08:49,986 - __main__ - INFO >>> =================================================
# 2022-08-02 18:08:49,987 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 63.346956695080735
# 2022-08-02 18:08:49,987 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 63.16074834238569
# 2022-08-02 18:08:49,988 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 0.014102383728816824
# 2022-08-02 18:08:49,989 - __main__ - INFO >>> Sleeping for 60 seconds ...
# 2022-08-02 18:09:50,100 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:09:50,101 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "analyze-sentence",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/podf180d417-a88c-481b-878c-f0d798ff4518/cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "image": "docker.io/phyz1x/analyze-sentence:1.0.0",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "analyze-sentence-6f64d86778-96l9f",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456588.798,
#                     "0.0050946222222490985"
#                 ]
#             },
#             {
#                 "metric": {
#                     "container": "nodeinfo",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/pod57d80e61-eb4a-40fb-afce-c09dffd6f567/0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "image": "ghcr.io/openfaas/nodeinfo:latest",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-cbbfc686d-sv5xm",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456588.798,
#                     "0.00264031111111112"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:09:50,207 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:09:50,208 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456588.906,
#                     "0.07212711111115151"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:09:50,307 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:09:50,308 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659456589.005,
#                     "35.2852230507724"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:09:50,406 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:09:50,407 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456589.102,
#                     "0.007641933333373648"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:09:50,407 - __main__ - INFO >>> {'odroidxu4-1': 35.2852230507724}
# 2022-08-02 18:09:50,408 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.10595091381931329}}
# 2022-08-02 18:09:50,408 - __main__ - INFO >>> =================================================
# 2022-08-02 18:09:50,410 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 35.2852230507724
# 2022-08-02 18:09:50,410 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 3.7385016265476336
# 2022-08-02 18:09:50,511 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:09:50,512 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456589.208,
#                     "0.07840706666669627"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:09:50,610 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:09:50,610 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456589.31,
#                     "0.0022248888888888587"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:09:50,611 - __main__ - INFO >>> {'odroidxu4-1': 35.2852230507724}
# 2022-08-02 18:09:50,612 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.10595091381931329}, 'nodeinfo': {'odroidxu4-1': 0.028376127095109015}}
# 2022-08-02 18:09:50,612 - __main__ - INFO >>> =================================================
# 2022-08-02 18:09:50,613 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 35.2852230507724
# 2022-08-02 18:09:50,614 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 3.7385016265476336
# 2022-08-02 18:09:50,615 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 1.0012579738679879
# 2022-08-02 18:09:50,615 - __main__ - INFO >>> Sleeping for 60 seconds ...
# 2022-08-02 18:10:50,728 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:10:50,729 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "analyze-sentence",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/podf180d417-a88c-481b-878c-f0d798ff4518/cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "image": "docker.io/phyz1x/analyze-sentence:1.0.0",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "analyze-sentence-6f64d86778-96l9f",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456649.425,
#                     "0.002812911111120936"
#                 ]
#             },
#             {
#                 "metric": {
#                     "container": "nodeinfo",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/pod57d80e61-eb4a-40fb-afce-c09dffd6f567/0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "image": "ghcr.io/openfaas/nodeinfo:latest",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-cbbfc686d-sv5xm",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456649.425,
#                     "0.0032457555555555394"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:10:50,831 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:10:50,832 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456649.528,
#                     "0.07329593333334657"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:10:50,934 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:10:50,935 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659456649.632,
#                     "9.434512170611924"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:10:51,038 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:10:51,039 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456649.734,
#                     "0.002812911111120936"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:10:51,040 - __main__ - INFO >>> {'odroidxu4-1': 9.434512170611924}
# 2022-08-02 18:10:51,041 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.038377451288162806}}
# 2022-08-02 18:10:51,041 - __main__ - INFO >>> =================================================
# 2022-08-02 18:10:51,042 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 9.434512170611924
# 2022-08-02 18:10:51,043 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.36207253125523825
# 2022-08-02 18:10:51,154 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:10:51,155 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456649.85,
#                     "0.07329593333334657"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:10:51,256 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:10:51,257 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456649.954,
#                     "0.0032457555555555394"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:10:51,258 - __main__ - INFO >>> {'odroidxu4-1': 9.434512170611924}
# 2022-08-02 18:10:51,258 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.038377451288162806}, 'nodeinfo': {'odroidxu4-1': 0.044282887302819256}}
# 2022-08-02 18:10:51,259 - __main__ - INFO >>> =================================================
# 2022-08-02 18:10:51,259 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 9.434512170611924
# 2022-08-02 18:10:51,260 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.36207253125523825
# 2022-08-02 18:10:51,260 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 0.41778743920828454
# 2022-08-02 18:10:51,260 - __main__ - INFO >>> Sleeping for 60 seconds ...
# 2022-08-02 18:11:51,374 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:11:51,375 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "analyze-sentence",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/podf180d417-a88c-481b-878c-f0d798ff4518/cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "image": "docker.io/phyz1x/analyze-sentence:1.0.0",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "analyze-sentence-6f64d86778-96l9f",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456710.072,
#                     "0.002479733333327911"
#                 ]
#             },
#             {
#                 "metric": {
#                     "container": "nodeinfo",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/pod57d80e61-eb4a-40fb-afce-c09dffd6f567/0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "image": "ghcr.io/openfaas/nodeinfo:latest",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-cbbfc686d-sv5xm",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456710.072,
#                     "0.002874866666666678"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:11:51,472 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:11:51,473 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456710.171,
#                     "0.06663575555554692"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:11:51,572 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:11:51,573 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659456710.27,
#                     "10.132465627850252"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:11:51,675 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:11:51,676 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456710.371,
#                     "0.002479733333327911"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:11:51,677 - __main__ - INFO >>> {'odroidxu4-1': 10.132465627850252}
# 2022-08-02 18:11:51,677 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.037213254545614464}}
# 2022-08-02 18:11:51,678 - __main__ - INFO >>> =================================================
# 2022-08-02 18:11:51,679 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 10.132465627850252
# 2022-08-02 18:11:51,679 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.3770620225838807
# 2022-08-02 18:11:51,778 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:11:51,779 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456710.475,
#                     "0.06663575555554692"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:11:51,879 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:11:51,883 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456710.572,
#                     "0.002874866666666678"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:11:51,886 - __main__ - INFO >>> {'odroidxu4-1': 10.132465627850252}
# 2022-08-02 18:11:51,888 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.037213254545614464}, 'nodeinfo': {'odroidxu4-1': 0.043143003972847836}}
# 2022-08-02 18:11:51,889 - __main__ - INFO >>> =================================================
# 2022-08-02 18:11:51,892 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 10.132465627850252
# 2022-08-02 18:11:51,893 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.3770620225838807
# 2022-08-02 18:11:51,896 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 0.43714500483708757
# 2022-08-02 18:11:51,897 - __main__ - INFO >>> Sleeping for 60 seconds ...
# 2022-08-02 18:12:52,005 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:12:52,006 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "analyze-sentence",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/podf180d417-a88c-481b-878c-f0d798ff4518/cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "image": "docker.io/phyz1x/analyze-sentence:1.0.0",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "cecc6fc7293a422f1834867c2b3c5f32d046332fa76d2ea2ec5080df9dd6278a",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "analyze-sentence-6f64d86778-96l9f",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456770.7,
#                     "0.004475577777783554"
#                 ]
#             },
#             {
#                 "metric": {
#                     "container": "nodeinfo",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/besteffort/pod57d80e61-eb4a-40fb-afce-c09dffd6f567/0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "image": "ghcr.io/openfaas/nodeinfo:latest",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "0c77cd4760ab5f81a591f1f6af38f20638f91c8be20f1885e39536b22095da48",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-cbbfc686d-sv5xm",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659456770.7,
#                     "0.0024945999999999914"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:12:52,101 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:12:52,102 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456770.797,
#                     "0.08797251111111672"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:12:52,201 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:12:52,202 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659456770.897,
#                     "9.975136856854078"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:12:52,307 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:12:52,308 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456771.005,
#                     "0.004475577777783554"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:12:52,309 - __main__ - INFO >>> {'odroidxu4-1': 9.975136856854078}
# 2022-08-02 18:12:52,309 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.05087473031354671}}
# 2022-08-02 18:12:52,310 - __main__ - INFO >>> =================================================
# 2022-08-02 18:12:52,310 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 9.975136856854078
# 2022-08-02 18:12:52,311 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.5074823974331713
# 2022-08-02 18:12:52,409 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:12:52,410 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456771.104,
#                     "0.08797251111111672"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:12:52,505 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:12:52,506 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659456771.201,
#                     "0.0024945999999999914"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:12:52,506 - __main__ - INFO >>> {'odroidxu4-1': 9.975136856854078}
# 2022-08-02 18:12:52,507 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.05087473031354671}, 'nodeinfo': {'odroidxu4-1': 0.028356585125200083}}
# 2022-08-02 18:12:52,508 - __main__ - INFO >>> =================================================
# 2022-08-02 18:12:52,509 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 9.975136856854078
# 2022-08-02 18:12:52,510 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.5074823974331713
# 2022-08-02 18:12:52,511 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 0.28286081741690344
# 2022-08-02 18:12:52,511 - __main__ - INFO >>> Sleeping for 60 seconds ...
# 2022-08-02 18:13:52,644 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:13:52,646 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
# ...
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-55ccfffbd9-gsgxk",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659457680.931,
#                     "0.003339044444444362"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:28:02,344 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:28:02,345 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457681.028,
#                     "0.061318600000000195"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:28:02,449 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:28:02,450 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659457681.134,
#                     "9.868255737064828"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:28:02,546 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:28:02,547 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457681.23,
#                     "0.005830422222223003"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:28:02,547 - __main__ - INFO >>> {'odroidxu4-1': 9.868255737064828}
# 2022-08-02 18:28:02,548 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.09508407273197667}}
# 2022-08-02 18:28:02,549 - __main__ - INFO >>> =================================================
# 2022-08-02 18:28:02,549 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 9.868255737064828
# 2022-08-02 18:28:02,550 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.9383139462408181
# 2022-08-02 18:28:02,645 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:28:02,646 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457681.331,
#                     "0.061318600000000195"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:28:02,742 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:28:02,743 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457681.426,
#                     "0.003339044444444362"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:28:02,744 - __main__ - INFO >>> {'odroidxu4-1': 9.868255737064828}
# 2022-08-02 18:28:02,744 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.09508407273197667}, 'nodeinfo': {'odroidxu4-1': 0.05445402283229479}}
# 2022-08-02 18:28:02,745 - __main__ - INFO >>> =================================================
# 2022-08-02 18:28:02,746 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 9.868255737064828
# 2022-08-02 18:28:02,746 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.9383139462408181
# 2022-08-02 18:28:02,747 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 0.5373662232210522
# 2022-08-02 18:28:02,747 - __main__ - INFO >>> Sleeping for 60 seconds ...
# 2022-08-02 18:29:02,860 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:29:02,861 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "analyze-sentence",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/burstable/pod7ca32260-1596-49e3-809d-46a862b44d80/b06132b4acf36c610f51d32828dabfd59d5ac676e07f1a534c121fbc9e2b4425",
#                     "image": "docker.io/phyz1x/analyze-sentence:1.0.0",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "b06132b4acf36c610f51d32828dabfd59d5ac676e07f1a534c121fbc9e2b4425",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "analyze-sentence-7787f8cfb9-wp62t",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659457741.543,
#                     "0.0034902888888887493"
#                 ]
#             },
#             {
#                 "metric": {
#                     "container": "nodeinfo",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/burstable/pod9e092e7b-1e57-4133-bdd1-1d39a15bb840/c1d500899c1909aff03b16e667a9c0d2f5fda7f2e8f63804950775dd415a1ac1",
#                     "image": "ghcr.io/openfaas/nodeinfo:latest",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "c1d500899c1909aff03b16e667a9c0d2f5fda7f2e8f63804950775dd415a1ac1",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-55ccfffbd9-gsgxk",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659457741.543,
#                     "0.00531931111111103"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:29:02,960 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:29:02,962 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457741.642,
#                     "0.0779911333333038"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:29:03,060 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:29:03,061 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659457741.743,
#                     "9.538663759411065"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:29:03,152 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:29:03,153 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457741.836,
#                     "0.0034902888888887493"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:29:03,153 - __main__ - INFO >>> {'odroidxu4-1': 9.538663759411065}
# 2022-08-02 18:29:03,154 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.0447523806837453}}
# 2022-08-02 18:29:03,155 - __main__ - INFO >>> =================================================
# 2022-08-02 18:29:03,156 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 9.538663759411065
# 2022-08-02 18:29:03,157 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.42687791177540907
# 2022-08-02 18:29:03,250 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:29:03,250 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457741.934,
#                     "0.0779911333333038"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:29:03,353 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:29:03,353 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457742.035,
#                     "0.00531931111111103"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:29:03,354 - __main__ - INFO >>> {'odroidxu4-1': 9.538663759411065}
# 2022-08-02 18:29:03,354 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.0447523806837453}, 'nodeinfo': {'odroidxu4-1': 0.06820404940621085}}
# 2022-08-02 18:29:03,355 - __main__ - INFO >>> =================================================
# 2022-08-02 18:29:03,355 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 9.538663759411065
# 2022-08-02 18:29:03,357 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 0.42687791177540907
# 2022-08-02 18:29:03,358 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 0.6505754943161052
# 2022-08-02 18:29:03,359 - __main__ - INFO >>> Sleeping for 60 seconds ...
# 2022-08-02 18:30:03,477 - __main__ - INFO >>> FUNCTION CONTAINER CPU USAGES
# 2022-08-02 18:30:03,478 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "analyze-sentence",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/burstable/pod7ca32260-1596-49e3-809d-46a862b44d80/b06132b4acf36c610f51d32828dabfd59d5ac676e07f1a534c121fbc9e2b4425",
#                     "image": "docker.io/phyz1x/analyze-sentence:1.0.0",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "b06132b4acf36c610f51d32828dabfd59d5ac676e07f1a534c121fbc9e2b4425",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "analyze-sentence-7787f8cfb9-wp62t",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659457802.159,
#                     "0.0071291555555540575"
#                 ]
#             },
#             {
#                 "metric": {
#                     "container": "nodeinfo",
#                     "cpu": "total",
#                     "endpoint": "https-metrics",
#                     "id": "/kubepods/burstable/pod9e092e7b-1e57-4133-bdd1-1d39a15bb840/c1d500899c1909aff03b16e667a9c0d2f5fda7f2e8f63804950775dd415a1ac1",
#                     "image": "ghcr.io/openfaas/nodeinfo:latest",
#                     "instance": "131.159.84.99:10250",
#                     "job": "kubelet",
#                     "metrics_path": "/metrics/cadvisor",
#                     "name": "c1d500899c1909aff03b16e667a9c0d2f5fda7f2e8f63804950775dd415a1ac1",
#                     "namespace": "openfaas-fn",
#                     "node": "odroidxu4-1",
#                     "pod": "nodeinfo-55ccfffbd9-gsgxk",
#                     "service": "kubelet"
#                 },
#                 "value": [
#                     1659457802.159,
#                     "0.0017682444444444753"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:30:03,590 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:30:03,593 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457802.271,
#                     "0.06208131111113088"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:30:03,695 - __main__ - INFO >>> ENERGY CONSUMPTION OF NODE ODROIDXU4-1
# 2022-08-02 18:30:03,696 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {
#                     "container": "power-exporter",
#                     "endpoint": "http",
#                     "instance": "odroidxu4-1",
#                     "job": "power-exporter",
#                     "namespace": "monitoring",
#                     "pod": "power-exporter-4cpj8",
#                     "service": "power-exporter"
#                 },
#                 "value": [
#                     1659457802.377,
#                     "9.54154500675213"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:30:03,797 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER ANALYZE-SENTENCE ON NODE ODROIDXU4-1
# 2022-08-02 18:30:03,798 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457802.478,
#                     "0.0071291555555540575"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:30:03,799 - __main__ - INFO >>> {'odroidxu4-1': 9.54154500675213}
# 2022-08-02 18:30:03,799 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.11483577630621003}}
# 2022-08-02 18:30:03,800 - __main__ - INFO >>> =================================================
# 2022-08-02 18:30:03,800 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 9.54154500675213
# 2022-08-02 18:30:03,801 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 1.095710728011023
# 2022-08-02 18:30:03,904 - __main__ - INFO >>> NODE CPU USAGE SUM OF NODE ODROIDXU4-1
# 2022-08-02 18:30:03,905 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457802.587,
#                     "0.06208131111113088"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:30:04,012 - __main__ - INFO >>> SUM OF CPU USAGE OF CONTAINER NODEINFO ON NODE ODROIDXU4-1
# 2022-08-02 18:30:04,013 - __main__ - INFO >>> {
#     "status": "success",
#     "data": {
#         "resultType": "vector",
#         "result": [
#             {
#                 "metric": {},
#                 "value": [
#                     1659457802.692,
#                     "0.0017682444444444753"
#                 ]
#             }
#         ]
#     }
# }
# 2022-08-02 18:30:04,013 - __main__ - INFO >>> {'odroidxu4-1': 9.54154500675213}
# 2022-08-02 18:30:04,014 - __main__ - INFO >>> {'analyze-sentence': {'odroidxu4-1': 0.11483577630621003}, 'nodeinfo': {'odroidxu4-1': 0.028482717468372498}}
# 2022-08-02 18:30:04,014 - __main__ - INFO >>> =================================================
# 2022-08-02 18:30:04,014 - __main__ - INFO >>> Energy Consumption of odroidxu4-1 = 9.54154500675213
# 2022-08-02 18:30:04,015 - __main__ - INFO >>> Energy Consumption (analyze-sentence | odroidxu4-1) = 1.095710728011023
# 2022-08-02 18:30:04,015 - __main__ - INFO >>> Energy Consumption (nodeinfo | odroidxu4-1) = 0.2717691306390813
# 2022-08-02 18:30:04,016 - __main__ - INFO >>> Sleeping for 60 seconds ...
